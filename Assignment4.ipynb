# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
accuracies_SVHN = np.load('C:\ADARSH\semester_6\DL\Assignment_4\naswot_accs_nasbench201_SVHN_True')
accuracies_cifar10 = np.load('C:\ADARSH\semester_6\DL\Assignment_4\naswot_accs_nasbench201_cifar10_original_True.npy')

scores_SVHN = np.load('C:\ADARSH\semester_6\DL\Assignment_4\naswot_hook_logdet_nasbench201_SVHN__none_0.05_1_True_128_1_1')
scores_cifar10 = np.load('C:\ADARSH\semester_6\DL\Assignment_4\naswot_hook_logdet_nasbench201_cifar10_original__none_0.05_1_True_128_1_1.npy')

# %% [markdown]
# Score v/s Model Accuracy for SVHN dataset

# %%
plt.plot(accuracies_SVHN, scores_SVHN, 'o')

# %% [markdown]
# Score v/s model accuracy for CIFAR 10 dataset

# %%
plt.plot(accuracies_cifar10, scores_cifar10, 'o')
